# %%
import pandas as pd

# %%
# %pip install camelot-py[cv]
# Out:
# ...
# WARNING: camelot-py 1.0.9 does not provide the extra 'cv'
# ...

# %%
import camelot
camelot.__version__
# Out:
# '1.0.9'

# %%
# Read PDF file
tables = camelot.read_pdf('./Voters_information.pdf', pages='1-end')
# Convert tables to DataFrames and save as CSV
tables[0].to_csv('results.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3825616045.py in <cell line: 0>()
#       1 # Read PDF file
# ----> 2 tables = camelot.read_pdf('./Voters_information.pdf', pages='1-end')
#       3 # Convert tables to DataFrames and save as CSV
#       4 tables[0].to_csv('results.csv')
#
# /usr/local/lib/python3.12/dist-packages/camelot/io.py in read_pdf(filepath, pages, password, flavor, suppress_stdout, parallel, layout_kwargs, debug, **kwargs)
#     130
#     131         validate_input(kwargs, flavor=flavor)
# --> 132         p = PDFHandler(filepath, pages=pages, password=password, debug=debug)
#     133         kwargs = remove_extra(kwargs, flavor=flavor)
#     134         tables = p.parse(
#
# /usr/local/lib/python3.12/dist-packages/camelot/handlers.py in __init__(self, filepath, pages, password, debug)
#      76         else:
# ...
